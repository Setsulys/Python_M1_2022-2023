# %% [markdown]
# # Exercice 1

# %%
from urllib.request import urlopen
from html.parser import HTMLParser
from urllib.request import urlretrieve
import os
from time import strftime

# %%
class htmlparsing(HTMLParser):
    def reset(self):                              
        HTMLParser.reset(self)
        self.urls = []
        
    def handle_starttag(self, tag, attrs):                     
        src = [v for k, v in attrs if k=='src']
        if src:
            self.urls.extend(src)
    

def dlimgs (url):
    s = urlopen(url).read().decode('utf8')
    p = htmlparsing()
    p.feed(s)
    p.close()
    for u in p.urls: 
        try :
            filename = os.path.join("./imgs", strftime("%Y-%m-%d_%H-%M-%S_")+u)
            print(urlretrieve(url+u,filename))
        except:
            pass

# %%
dlimgs('http://www-igm.univ-mlv.fr/~jyt/')
# Out:
# ('./imgs/2022-10-19_11-53-06_logoigm.gif', <http.client.HTTPMessage object at 0x7f933c202a58>)
# ('./imgs/2022-10-19_11-53-06_titre-petit.jpg', <http.client.HTTPMessage object at 0x7f933c2027f0>)
# ('./imgs/2022-10-19_11-53-06_barre.gif', <http.client.HTTPMessage object at 0x7f933c2025c0>)
# ('./imgs/2022-10-19_11-53-06_logoCNRS.jpg', <http.client.HTTPMessage object at 0x7f933c202908>)
# ('./imgs/2022-10-19_11-53-06_thibon.gif', <http.client.HTTPMessage object at 0x7f933c202ba8>)
# ('./imgs/2022-10-19_11-53-06_mail.gif', <http.client.HTTPMessage object at 0x7f933c202a58>)
# ('./imgs/2022-10-19_11-53-07_iuf.gif', <http.client.HTTPMessage object at 0x7f933c2027f0>)

# %% [markdown]
# # Exerice2

# %%
import xmlrpc.client as cli
import base64

# %%
with cli.ServerProxy("http://monge.univ-mlv.fr:8888") as proxy:
    #print(proxy.system.listMethods())
    print(str(proxy.jure())+" : "+base64.b64decode(str(proxy.jure())).decode('latin-1'))
    base64.b64decode(proxy.jure().data).decode('latin-1')
# Out:
# VmllaWxsZSBjb3F1ZSByb3VpbGzpZQo= : Espèce d'apprenti dictateur à  la noix de coco

# %%
print(base64.b64decode(str(proxy.tous_les_jurons())).decode('latin-1'))
# Out:
# Abominable
# Accapareurs
# Amphitryon
# Anacoluthe
# Anacoluthes
# Analphabète
# Analphabètes
# Animal
# Anthropophage
# Anthropopithèque
# Anthropopitèque
# Anthropopitèques
# Apache
# Appareil de malheur
# Arlequin
# Astronaute d'eau douce
# Autocrates
# Autodidactes
# Aztèques
# Bachi-Bouzouk
# Bachi-Bouzouks
# Bande d'ectoplasmes de tonnerre de Brest
# Bande d'emplâtres
# Bande d'escrocs
# Bande de Bachi-bouzouks
# Bande de Ku-Klux-Klans
# Bande de Zapotèques
# Bande de brutes
# Bande de canaques
# Bande de jeunes effrontés
# Bande de pirates
# Bande de rats
# Bande de sauvages
# Bande de voleurs
# Bande de zapotèques de tonnerre de Brest
# Bandes de canaques
# Bandes de zapotèques
# Bandit
# Bandits
# Barbares
# Bayadère de carnaval
# Boit-sans-soif
# Bougre d'amiral de bateau-lavoir
# Bougre d'ectoplasme de moule à gaufres
# Bougre d'extrait d'hydrocarbure
# Bougre d'extrait de cornichon
# Bougre d'olibrius
# Bougre de Tintin
# ...

# %% [markdown]
# # Exercice3
